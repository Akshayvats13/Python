# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_abs = pd.read_excel('Absenteeism_at_work.xls')

# %%
df_abs.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
# ...

# %%
df_abs.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %% [markdown]
# # EDA

# %%
df_abs.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df_abs.corr()
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.092457           -0.123472
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# ...

# %%
sns.kdeplot(df_abs['Absenteeism time in hours'])
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(df_abs['Body mass index'])
#mostly employees have 24-31 bmi.
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(df_abs['Height'])
#maximum height in employees is 175.
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(df_abs['Weight'])
#there are two peaks coming means majorly there are two maximum weight of employees : 30 and 34.
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
vc1 = df_abs['Social smoker'].value_counts()
vc1.plot(kind='bar')
#extremely less proportion of employees are non social smoker

# %%
vc2 = df_abs['Social drinker'].value_counts()
vc2.plot(kind='bar')

# %% [markdown]
# Proportion of employees who are social drinker are more compared to non social drinkers.

# %%
vc3 = df_abs['Son'].value_counts()
vc3.plot(kind='bar')

# %% [markdown]
# Number of employees who have 0 sons are maximum.

# %%
vc4 = df_abs['Education'].value_counts()
vc4.plot(kind='bar')

# %% [markdown]
# Maximum employees have had education till high school

# %%
vc5 = df_abs['Disciplinary failure'].value_counts()
vc5.plot(kind='bar')

# %% [markdown]
# Proportion of employees who didnt had discp.failure are extremely less compared to those have had.

# %%
sns.kdeplot(df_abs['Hit target'])
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Maximum target to hit is 90-99

# %%
sns.kdeplot(df_abs['Work load Average/day '])
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Inferences: maximum employees have 250000 avg load.

# %%
sns.kdeplot(df_abs['Age'])
#40 is max avg age.
# Out:
# C:\Users\AKSHAY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # PCA

# %%
#Improting the PCA module
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized', random_state=42)

# %%
#standardizing x
from sklearn.preprocessing import StandardScaler
df_std=StandardScaler().fit_transform(df_abs)

# %%
#Doing the PCA on the train data
pca.fit(df_std)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=42,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[-2.14698325e-01,  3.59945607e-02,  1.52110247e-02,
#         -3.94466988e-02, -2.93165694e-02, -1.32027597e-01,
#          1.17791951e-01,  4.19130783e-01,  3.45831580e-01,
#         -4.16592529e-02, -5.70271550e-02,  3.40288796e-02,
#         -2.52778243e-01, -3.65814489e-02,  3.32635813e-01,
#         -7.80275653e-02, -1.66716872e-01,  4.43903626e-01,
#          1.84867035e-02,  4.58132177e-01,  1.40904787e-02],
#        [-3.08571019e-01,  3.91345342e-03,  1.80581280e-01,
#          7.41232590e-02,  4.70673377e-02,  4.74003896e-01,
#          4.58755062e-01, -1.24427991e-01, -1.64415838e-01,
#         -4.79029811e-02, -1.45579104e-01,  7.38870201e-02,
#         -1.99217610e-01,  2.66949719e-01,  2.80712557e-01,
#          3.17316732e-03,  3.12811659e-01, -9.35480038e-02,
#         -2.45770953e-01,  1.05884271e-02, -3.12107124e-02],
#        [ 1.89484613e-01, -4.82110401e-01,  3.57730717e-01,
#         -9.80311972e-02,  3.32919350e-01,  8.67260893e-02,
# ...

# %%
colnames = list(df_abs.columns)
pcs_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1], 'Feature':colnames})
pcs_df.head()
# Out:
#         PC1       PC2             Feature
# 0 -0.214698 -0.308571                  ID
# 1  0.035995  0.003913  Reason for absence
# 2  0.015211  0.180581    Month of absence
# 3 -0.039447  0.074123     Day of the week
# 4 -0.029317  0.047067             Seasons

# %%
pca.explained_variance_ratio_
# Out:
# array([1.64011962e-01, 1.14189319e-01, 9.64674259e-02, 7.32827125e-02,
#        6.83020569e-02, 6.21072796e-02, 5.47847129e-02, 5.39310454e-02,
#        4.77352065e-02, 4.47594082e-02, 4.30115151e-02, 3.79360445e-02,
#        3.41678421e-02, 2.23418213e-02, 2.02388938e-02, 1.77523857e-02,
#        1.44336383e-02, 1.20348781e-02, 1.12177681e-02, 7.17181011e-03,
#        1.22274071e-04])

# %%
#Making the screeplot - plotting the cumulative variance against the number of components
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# # 12 features are explaining 95% variance hence building clusters using first 12 features

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans
from scipy.stats import zscore

# %%
x = df_abs.drop(columns=['Education', 'Son', 'Social drinker',
       'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
       'Absenteeism time in hours'])

# %%
Y = df_abs['Absenteeism time in hours']

# %%
#scaling reduced independent variable 
df_scaled=x.apply(zscore)

# %%
cluster_range=range(1,15)
cluster_errors=[]
for num_cluster in cluster_range:
    clusters=KMeans(num_cluster, n_init=10)
    clusters.fit(df_scaled)
    labels=clusters.labels_
    centroids=clusters.cluster_centers_
    cluster_errors.append(clusters.inertia_)
clusters_df=pd.DataFrame({"num_clusters":cluster_range, "cluster_errors":cluster_errors})
clusters_df[0:15]
# Out:
#     num_clusters  cluster_errors
# 0              1     8880.000000
# 1              2     7824.369238
# 2              3     6954.278010
# 3              4     6191.680352
# 4              5     5629.699833
# 5              6     5282.681498
# 6              7     4977.864727
# 7              8     4706.292169
# 8              9     4479.752788
# 9             10     4303.910492
# 10            11     4166.283249
# 11            12     4097.082363
# 12            13     3946.568233
# 13            14     3840.311071

# %%
#elbow plot
plt.figure(figsize=(12,6))
plt.plot(clusters_df.num_clusters, clusters_df.cluster_errors, marker="o")

# %% [markdown]
# # 6 optimum number of clusters

# %%
#model fitting  : 
kmeans=KMeans(n_clusters=6, n_init=15, random_state=2345)
kmeans.fit(df_scaled)
centroids=kmeans.cluster_centers_
centroid_df=pd.DataFrame(centroids, columns=list(df_scaled))
kmeans.labels_
pd.DataFrame(kmeans.labels_, columns=["label"]).head()
# Out:
#    label
# 0      5
# 1      3
# 2      1
# 3      5
# 4      5

# %% [markdown]
# # Creating a new dataframe only for labels and converting it into categorical variable

# %%
df_labels=pd.DataFrame(kmeans.labels_, columns=list(['labels']))
df_labels['labels']=df_labels["labels"].astype("category")

# %% [markdown]
# # #joining the label dataframe with the original dataframe

# %%
abs_df_labeled=df_abs.join(df_labels)
df_analysis=(abs_df_labeled.groupby(['labels'],axis=0)).head()
df_analysis
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# 5     3                  23                 7                6        1
# 6    10                  22                 7                6        1
# 7    20                  23                 7                6        1
# 8    14                  19                 7                2        1
# 9     1                  22                 7                2        1
# 13    3                  11                 7                4        1
# 14    3                  23                 7                4        1
# ...

# %%
#checking value counts of clusters labels
abs_df_labeled["labels"].value_counts()
# Out:
# 0    169
# 4    166
# 2    143
# 1    112
# 5    110
# 3     40
# Name: labels, dtype: int64

# %% [markdown]
# # inferences: 169 records in are cluster 0, 166 in cluster 4, 143 in cluster 2,112 in cluster 1, 110 in cluster 5, 40 in cluster 3
